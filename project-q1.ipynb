# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torchvision.models import ResNet18_Weights
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from torch.utils.data import DataLoader, random_split, Subset , Dataset
import torch.nn.functional as F
import pandas as pd

# %%
class ResNet18(nn.Module):
    def __init__(self):
        super(ResNet18, self).__init__()
        self.model = models.resnet18(weights=ResNet18_Weights.DEFAULT)
        self.model.fc = nn.Sequential(
            nn.Linear(self.model.fc.in_features, 512),
            nn.ReLU() ,
            nn.Linear(512, 128) ,
            nn.ReLU() ,
            nn.Linear(128, 10)
        )
    def forward(self, x):
        return self.model(x)

def train_model(model, train_loader, criterion, optimizer, scheduler, num_epochs, s,all_epoch_print=False):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            if inputs.shape[0] == 1:
                continue
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
        epoch_loss = running_loss / len(train_loader.dataset)
        scheduler.step(epoch_loss)
        if all_epoch_print:
            print(f'{epoch_loss:.6f} , ' if s+1 >= 10 else f'{epoch_loss:.5f} , ', end='')
        else:
            if epoch == num_epochs-1:
                print(f'{epoch_loss:.6f} , ' if s+1 >= 10 else f'{epoch_loss:.5f} , ', end='')

# %%
# Define transformation for the CIFAR-10 dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
len_train_dataset , len_test_dataset = len(train_dataset) , len(test_dataset)

num_shards_list = [5,10,20]
num_slice_list = [5,10,20]
num_epoch_shard = 60

for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        print(f"-- Training with {num_shards} shard and {num_slice} slices started --")
        indices = np.arange(len_train_dataset)
        shard_size = len_train_dataset // num_shards
        shards_indices = [indices[i * shard_size:(i + 1) * shard_size] for i in range(num_shards)]

        for i, shard_indices in enumerate(shards_indices):
            print(f"  -- Training on shard {i+1} / {num_shards} --")
            print('      '+', '.join([f'slice1-{i+1}' for i in range(num_slice)]))
            print('      ',end='')
            slice_size = shard_size // num_slice
            slices_indices = np.array([shard_indices[i * slice_size:(i + 1) * slice_size] for i in range(num_slice)])

            model = ResNet18().to(device)
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.8)
            scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)
            
            for s in range(num_slice):
                base_indices = slices_indices[:s+1,:].reshape(-1,)
                slice_dataset = Subset(train_dataset,base_indices)
                loader = DataLoader(slice_dataset, batch_size=32, shuffle=True)
                train_model(model, loader, criterion, optimizer, scheduler, num_epochs=num_epoch_shard//num_slice,s=s)
            print(f' with {num_epoch_shard//num_slice} epochs')
            torch.save(model.state_dict(),f'M_S{num_shards}_R{num_slice}_shard{i+1}.pth')
# Out:
# cuda
# Files already downloaded and verified
# Files already downloaded and verified
# -- Training with 5 shard and 5 slices started --
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.18652 , 0.04293 , 0.01540 , 0.01382 , 0.01972 ,  with 12 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.23371 , 0.03193 , 0.01326 , 0.01201 , 0.02119 ,  with 12 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.23748 , 0.03597 , 0.01448 , 0.01165 , 0.01787 ,  with 12 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.17872 , 0.03739 , 0.01719 , 0.01292 , 0.03881 ,  with 12 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.25246 , 0.04602 , 0.02295 , 0.01243 , 0.01786 ,  with 12 epochs
# -- Training with 5 shard and 10 slices started --
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.82848 , 0.32270 , 0.24325 , 0.15989 , 0.13699 , 0.11338 , 0.07816 , 0.06659 , 0.02012 , 0.01429 ,  with 6 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.66133 , 0.36429 , 0.20883 , 0.19415 , 0.15328 , 0.10415 , 0.07902 , 0.08697 , 0.03872 , 0.01628 ,  with 6 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.59190 , 0.37042 , 0.23147 , 0.18142 , 0.07416 , 0.03472 , 0.03908 , 0.02100 , 0.02465 , 0.02610 ,  with 6 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.57938 , 0.28800 , 0.26174 , 0.14233 , 0.15254 , 0.03676 , 0.02942 , 0.01902 , 0.02165 , 0.02604 ,  with 6 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.73148 , 0.30772 , 0.23237 , 0.16821 , 0.13655 , 0.10327 , 0.06876 , 0.08076 , 0.05739 , 0.05465 ,  with 6 epochs
# -- Training with 5 shard and 20 slices started --
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.59258 , 0.92864 , 0.51166 , 0.40746 , 0.38060 , 0.25169 , 0.27002 , 0.22621 , 0.15686 , 0.16367 , 0.136191 , 0.121534 , 0.185829 , 0.124009 , 0.041763 , 0.035074 , 0.032938 , 0.036666 , 0.033777 , 0.024129 ,  with 3 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.61190 , 0.84117 , 0.51043 , 0.37861 , 0.37503 , 0.25358 , 0.25798 , 0.21257 , 0.17989 , 0.14327 , 0.143351 , 0.119016 , 0.346584 , 0.107444 , 0.072138 , 0.078550 , 0.085036 , 0.030700 , 0.023677 , 0.032155 ,  with 3 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.63675 , 0.79968 , 0.55649 , 0.43088 , 0.45934 , 0.30440 , 0.20661 , 0.16909 , 0.17437 , 0.19324 , 0.060913 , 0.058829 , 0.068010 , 0.048407 , 0.038468 , 0.039000 , 0.047246 , 0.035966 , 0.029838 , 0.026474 ,  with 3 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.59078 , 0.87091 , 0.45456 , 0.43322 , 0.79275 , 0.29278 , 0.23740 , 0.19138 , 0.18811 , 0.18501 , 0.134979 , 0.132573 , 0.172613 , 0.071305 , 0.038421 , 0.037037 , 0.033395 , 0.031007 , 0.030993 , 0.030505 ,  with 3 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.57680 , 0.82144 , 0.52801 , 0.44060 , 0.59760 , 0.26818 , 0.23991 , 0.20124 , 0.15985 , 0.24763 , 0.125244 , 0.097921 , 0.248274 , 0.096825 , 0.086807 , 0.079996 , 0.068799 , 0.073702 , 0.049605 , 0.048550 ,  with 3 epochs
# -- Training with 10 shard and 5 slices started --
#   -- Training on shard 1 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.33911 , 0.16770 , 0.08159 , 0.01168 , 0.01104 ,  with 12 epochs
#   -- Training on shard 2 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.40763 , 0.03293 , 0.02486 , 0.01722 , 0.02475 ,  with 12 epochs
#   -- Training on shard 3 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.28197 , 0.12378 , 0.02392 , 0.01303 , 0.01904 ,  with 12 epochs
#   -- Training on shard 4 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.30841 , 0.15891 , 0.03101 , 0.01445 , 0.01780 ,  with 12 epochs
#   -- Training on shard 5 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.31880 , 0.17542 , 0.02903 , 0.01417 , 0.01623 ,  with 12 epochs
#   -- Training on shard 6 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.43441 , 0.14283 , 0.07780 , 0.01350 , 0.01596 ,  with 12 epochs
#   -- Training on shard 7 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.24795 , 0.15396 , 0.02039 , 0.01510 , 0.01217 ,  with 12 epochs
#   -- Training on shard 8 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.31159 , 0.06232 , 0.01689 , 0.01653 , 0.02779 ,  with 12 epochs
#   -- Training on shard 9 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.25933 , 0.03033 , 0.01541 , 0.01729 , 0.05332 ,  with 12 epochs
#   -- Training on shard 10 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.32608 , 0.04390 , 0.01626 , 0.01898 , 0.05480 ,  with 12 epochs
# -- Training with 10 shard and 10 slices started --
#   -- Training on shard 1 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.49111 , 0.47818 , 0.20739 , 0.19173 , 0.24039 , 0.04958 , 0.04572 , 0.03510 , 0.04154 , 0.03019 ,  with 6 epochs
#   -- Training on shard 2 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.51502 , 0.59986 , 0.30465 , 0.20195 , 0.24738 , 0.13690 , 0.11236 , 0.09104 , 0.10949 , 0.04508 ,  with 6 epochs
#   -- Training on shard 3 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.57594 , 0.52981 , 0.25694 , 0.21246 , 0.06614 , 0.04085 , 0.04834 , 0.03144 , 0.03198 , 0.04040 ,  with 6 epochs
#   -- Training on shard 4 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.65463 , 0.45113 , 0.30033 , 0.21204 , 0.50617 , 0.15104 , 0.12436 , 0.08420 , 0.09641 , 0.01268 ,  with 6 epochs
#   -- Training on shard 5 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.63293 , 0.46174 , 0.29444 , 0.18431 , 0.33005 , 0.14171 , 0.13138 , 0.09119 , 0.07190 , 0.06260 ,  with 6 epochs
#   -- Training on shard 6 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.50444 , 0.43419 , 0.25632 , 0.25988 , 0.14942 , 0.05401 , 0.03629 , 0.03336 , 0.02702 , 0.04536 ,  with 6 epochs
#   -- Training on shard 7 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.58903 , 0.45555 , 0.20621 , 0.22215 , 0.06990 , 0.05572 , 0.04981 , 0.05197 , 0.02208 , 0.02068 ,  with 6 epochs
#   -- Training on shard 8 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.50393 , 0.46102 , 0.25417 , 0.08156 , 0.05782 , 0.06297 , 0.03678 , 0.02793 , 0.02984 , 0.03571 ,  with 6 epochs
#   -- Training on shard 9 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.61523 , 0.39179 , 0.23613 , 0.22319 , 0.08280 , 0.04643 , 0.06157 , 0.02791 , 0.02924 , 0.03849 ,  with 6 epochs
#   -- Training on shard 10 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.51535 , 0.35432 , 0.29597 , 0.21605 , 0.27403 , 0.03872 , 0.06846 , 0.03647 , 0.02746 , 0.03276 ,  with 6 epochs
# -- Training with 10 shard and 20 slices started --
#   -- Training on shard 1 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.90874 , 0.71561 , 0.48115 , 0.46437 , 0.80041 , 0.35106 , 0.26635 , 0.27760 , 0.17062 , 0.21279 , 0.169430 , 0.137868 , 0.111709 , 0.110624 , 0.141222 , 0.077384 , 0.098531 , 0.078333 , 0.036984 , 0.034911 ,  with 3 epochs
#   -- Training on shard 2 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.95369 , 0.75942 , 0.52528 , 0.57664 , 0.72430 , 0.51164 , 0.28188 , 0.20357 , 0.15516 , 0.19613 , 0.126348 , 0.109515 , 0.095920 , 0.062869 , 0.192631 , 0.077328 , 0.051064 , 0.040969 , 0.038592 , 0.037138 ,  with 3 epochs
#   -- Training on shard 3 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.90580 , 0.80550 , 0.61964 , 0.44797 , 1.38146 , 0.76472 , 0.36061 , 0.24673 , 0.26870 , 0.26750 , 0.143423 , 0.115306 , 0.095660 , 0.099182 , 0.121823 , 0.077689 , 0.088041 , 0.077821 , 0.086269 , 0.094213 ,  with 3 epochs
#   -- Training on shard 4 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.99933 , 0.67837 , 0.44159 , 0.40063 , 1.92693 , 0.99492 , 0.44423 , 0.26599 , 0.19333 , 0.38828 , 0.164945 , 0.150374 , 0.120728 , 0.153310 , 0.176848 , 0.066928 , 0.069357 , 0.058677 , 0.066064 , 0.058814 ,  with 3 epochs
#   -- Training on shard 5 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.95169 , 0.76448 , 0.54509 , 0.42883 , 1.80360 , 0.96576 , 0.40071 , 0.34644 , 0.21363 , 0.33080 , 0.192293 , 0.144571 , 0.136950 , 0.129072 , 0.111904 , 0.135020 , 0.103057 , 0.079979 , 0.079135 , 0.082221 ,  with 3 epochs
#   -- Training on shard 6 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.97069 , 0.81186 , 0.53031 , 0.43284 , 2.14301 , 1.58593 , 1.22007 , 0.99431 , 0.74600 , 0.65376 , 0.404271 , 0.361859 , 0.298473 , 0.303762 , 0.313278 , 0.220696 , 0.208942 , 0.184951 , 0.209981 , 0.192222 ,  with 3 epochs
#   -- Training on shard 7 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.98886 , 0.62259 , 0.53086 , 0.43973 , 2.00404 , 1.37064 , 0.87653 , 0.71767 , 0.43570 , 0.37791 , 0.273471 , 0.235115 , 0.234400 , 0.200842 , 0.205419 , 0.190821 , 0.159802 , 0.145043 , 0.132572 , 0.168894 ,  with 3 epochs
#   -- Training on shard 8 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.94954 , 0.70274 , 0.49623 , 0.43031 , 1.68487 , 1.05262 , 0.50410 , 0.36535 , 0.36176 , 0.25001 , 0.250633 , 0.167589 , 0.165275 , 0.155708 , 0.169494 , 0.111167 , 0.113361 , 0.104104 , 0.092138 , 0.108533 ,  with 3 epochs
#   -- Training on shard 9 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.98697 , 0.90031 , 0.57914 , 0.42325 , 1.83803 , 1.49219 , 1.10388 , 0.88639 , 0.61206 , 0.50880 , 0.418982 , 0.372355 , 0.294157 , 0.297975 , 0.275649 , 0.258498 , 0.210545 , 0.232019 , 0.204217 , 0.206831 ,  with 3 epochs
#   -- Training on shard 10 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.91309 , 0.77882 , 0.52932 , 0.37625 , 1.53782 , 0.97889 , 0.43557 , 0.38471 , 0.22729 , 0.22136 , 0.192166 , 0.158484 , 0.155093 , 0.148925 , 0.200035 , 0.116295 , 0.084780 , 0.098406 , 0.093090 , 0.077437 ,  with 3 epochs
# -- Training with 20 shard and 5 slices started --
#   -- Training on shard 1 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.34160 , 0.27104 , 0.02686 , 0.01387 , 0.04443 ,  with 12 epochs
#   -- Training on shard 2 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.26997 , 0.08244 , 0.05522 , 0.02040 , 0.06049 ,  with 12 epochs
#   -- Training on shard 3 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.21113 , 0.06244 , 0.01649 , 0.01620 , 0.03258 ,  with 12 epochs
#   -- Training on shard 4 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.23420 , 0.05397 , 0.03192 , 0.02418 , 0.07618 ,  with 12 epochs
#   -- Training on shard 5 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.29297 , 0.12106 , 0.03810 , 0.02429 , 0.05791 ,  with 12 epochs
#   -- Training on shard 6 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.21159 , 0.04843 , 0.02534 , 0.03619 , 0.06064 ,  with 12 epochs
#   -- Training on shard 7 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.33496 , 0.13164 , 0.02229 , 0.02331 , 0.07591 ,  with 12 epochs
#   -- Training on shard 8 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.44274 , 0.11924 , 0.03518 , 0.02180 , 0.07697 ,  with 12 epochs
#   -- Training on shard 9 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.26592 , 0.11703 , 0.02552 , 0.02720 , 0.07994 ,  with 12 epochs
#   -- Training on shard 10 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.29853 , 0.08957 , 0.05166 , 0.01388 , 0.04398 ,  with 12 epochs
#   -- Training on shard 11 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.24552 , 0.07619 , 0.01864 , 0.03119 , 0.06510 ,  with 12 epochs
#   -- Training on shard 12 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.23806 , 0.08838 , 0.01781 , 0.03287 , 0.06303 ,  with 12 epochs
#   -- Training on shard 13 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.35339 , 0.29057 , 0.07965 , 0.01658 , 0.05025 ,  with 12 epochs
#   -- Training on shard 14 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.18207 , 0.11172 , 0.05966 , 0.02028 , 0.03708 ,  with 12 epochs
#   -- Training on shard 15 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.29235 , 0.04460 , 0.02607 , 0.03298 , 0.08212 ,  with 12 epochs
#   -- Training on shard 16 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.31440 , 0.09917 , 0.02538 , 0.02757 , 0.04268 ,  with 12 epochs
#   -- Training on shard 17 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.24298 , 0.09222 , 0.02372 , 0.02989 , 0.09549 ,  with 12 epochs
#   -- Training on shard 18 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.27402 , 0.07385 , 0.01844 , 0.03348 , 0.07486 ,  with 12 epochs
#   -- Training on shard 19 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.29599 , 0.06182 , 0.06411 , 0.02055 , 0.02782 ,  with 12 epochs
#   -- Training on shard 20 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.15087 , 0.07349 , 0.04735 , 0.02362 , 0.02570 ,  with 12 epochs
# -- Training with 20 shard and 10 slices started --
#   -- Training on shard 1 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.87767 , 0.34633 , 0.34097 , 0.17705 , 0.88517 , 0.34416 , 0.16846 , 0.12078 , 0.12319 , 0.12431 ,  with 6 epochs
#   -- Training on shard 2 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.79376 , 0.18930 , 0.30725 , 0.08306 , 1.60262 , 0.95257 , 0.49547 , 0.35575 , 0.33494 , 0.41667 ,  with 6 epochs
#   -- Training on shard 3 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.83586 , 0.37034 , 0.32001 , 0.27486 , 1.89402 , 1.68628 , 1.39687 , 1.18989 , 1.06638 , 1.06233 ,  with 6 epochs
#   -- Training on shard 4 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.71506 , 0.38405 , 0.09018 , 0.14031 , 0.46763 , 0.14430 , 0.14098 , 0.16380 , 0.21165 , 0.28023 ,  with 6 epochs
#   -- Training on shard 5 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.70610 , 0.23324 , 0.27590 , 0.09385 , 1.11298 , 0.26331 , 0.14617 , 0.14880 , 0.17071 , 0.26918 ,  with 6 epochs
#   -- Training on shard 6 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.76469 , 0.36982 , 0.30609 , 0.21131 , 1.93934 , 1.54957 , 1.19892 , 1.00983 , 0.85851 , 0.84844 ,  with 6 epochs
#   -- Training on shard 7 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.86624 , 0.34776 , 0.21015 , 0.08500 , 1.04684 , 0.17573 , 0.11856 , 0.09773 , 0.16224 , 0.23731 ,  with 6 epochs
#   -- Training on shard 8 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.78180 , 0.24628 , 0.31008 , 0.12810 , 0.86868 , 0.17954 , 0.10544 , 0.12905 , 0.18124 , 0.24189 ,  with 6 epochs
#   -- Training on shard 9 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.80324 , 0.42520 , 0.33193 , 0.21728 , 1.14588 , 0.31688 , 0.14349 , 0.10712 , 0.10067 , 0.20137 ,  with 6 epochs
#   -- Training on shard 10 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.69336 , 0.42507 , 0.34475 , 0.09942 , 1.17045 , 0.31203 , 0.13169 , 0.16011 , 0.19109 , 0.25106 ,  with 6 epochs
#   -- Training on shard 11 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.85091 , 0.35026 , 0.27064 , 0.15164 , 0.69696 , 0.18120 , 0.12815 , 0.11154 , 0.10735 , 0.18001 ,  with 6 epochs
#   -- Training on shard 12 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.81690 , 0.26803 , 0.18608 , 0.15339 , 1.02460 , 0.27715 , 0.17223 , 0.14825 , 0.20252 , 0.25157 ,  with 6 epochs
#   -- Training on shard 13 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.75505 , 0.41430 , 0.31255 , 0.12680 , 1.63218 , 1.10985 , 0.75277 , 0.56534 , 0.55097 , 0.58296 ,  with 6 epochs
#   -- Training on shard 14 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.64433 , 0.27050 , 0.22670 , 0.22200 , 1.32465 , 0.22254 , 0.08772 , 0.09071 , 0.06551 , 0.10444 ,  with 6 epochs
#   -- Training on shard 15 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.81533 , 0.20983 , 0.32760 , 0.12775 , 0.58417 , 0.08186 , 0.08033 , 0.07803 , 0.04890 , 0.06752 ,  with 6 epochs
#   -- Training on shard 16 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.65947 , 0.36867 , 0.22667 , 0.31852 , 0.70755 , 0.41197 , 0.15380 , 0.12190 , 0.09739 , 0.12963 ,  with 6 epochs
#   -- Training on shard 17 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.72030 , 0.29143 , 0.38156 , 0.11739 , 1.54376 , 0.79391 , 0.45320 , 0.31613 , 0.33397 , 0.34997 ,  with 6 epochs
#   -- Training on shard 18 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.78145 , 0.38133 , 0.28190 , 0.34673 , 1.02391 , 0.17290 , 0.14928 , 0.10147 , 0.07973 , 0.13212 ,  with 6 epochs
#   -- Training on shard 19 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.62322 , 0.32534 , 0.19860 , 0.33776 , 0.74901 , 0.14577 , 0.07653 , 0.09270 , 0.07656 , 0.08860 ,  with 6 epochs
#   -- Training on shard 20 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.87772 , 0.39179 , 0.34369 , 0.16704 , 1.85702 , 1.28598 , 0.92569 , 0.65423 , 0.60570 , 0.59120 ,  with 6 epochs
# -- Training with 20 shard and 20 slices started --
#   -- Training on shard 1 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       1.98446 , 1.19904 , 0.43230 , 0.53588 , 0.33694 , 0.20722 , 0.41622 , 0.28103 , 0.13011 , 0.99440 , 0.310224 , 0.141872 , 0.102218 , 0.107962 , 0.070356 , 0.094248 , 0.093893 , 0.079015 , 0.086156 , 0.100129 ,  with 3 epochs
#   -- Training on shard 2 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.09778 , 1.37029 , 0.33258 , 0.39502 , 0.34202 , 0.16729 , 0.16298 , 0.20654 , 0.22552 , 0.28564 , 0.099462 , 0.086522 , 0.070502 , 0.067311 , 0.056533 , 0.080434 , 0.052693 , 0.067849 , 0.071019 , 0.059646 ,  with 3 epochs
#   -- Training on shard 3 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.08437 , 1.42024 , 0.53862 , 0.57144 , 0.36813 , 0.28083 , 0.34138 , 0.19148 , 0.43323 , 0.96239 , 0.139653 , 0.104065 , 0.076239 , 0.091498 , 0.055655 , 0.061822 , 0.079087 , 0.057131 , 0.075651 , 0.074225 ,  with 3 epochs
#   -- Training on shard 4 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.08975 , 1.40407 , 0.55591 , 0.48328 , 0.35109 , 0.30548 , 0.35774 , 0.27484 , 0.29922 , 1.70620 , 0.817208 , 0.447549 , 0.228824 , 0.171882 , 0.167695 , 0.151353 , 0.098831 , 0.098523 , 0.198014 , 0.149487 ,  with 3 epochs
#   -- Training on shard 5 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.06981 , 1.46876 , 0.44805 , 0.51244 , 0.39299 , 0.26095 , 0.27306 , 0.23331 , 0.28542 , 0.53870 , 0.147177 , 0.101375 , 0.078760 , 0.073988 , 0.075203 , 0.074604 , 0.061191 , 0.043092 , 0.060696 , 0.062635 ,  with 3 epochs
#   -- Training on shard 6 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.05864 , 1.30452 , 0.41622 , 0.46763 , 0.38419 , 0.24626 , 0.28918 , 0.23217 , 0.29540 , 1.49374 , 0.745290 , 0.449798 , 0.184684 , 0.129407 , 0.150167 , 0.128851 , 0.145195 , 0.104273 , 0.147919 , 0.306159 ,  with 3 epochs
#   -- Training on shard 7 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.03338 , 1.47323 , 0.50212 , 0.39173 , 0.45081 , 0.42021 , 0.12348 , 0.15928 , 0.127245 , 0.133363 , 0.136305 , 0.177759 , 0.202908 , 0.240435 ,  with 3 epochs
#   -- Training on shard 9 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.07821 , 1.29819 , 0.53285 , 0.34762 , 0.37602 , 0.21187 , 0.33327 , 0.19786 , 0.19815 , 1.01685 , 0.564742 , 0.262984 , 0.106534 , 0.096146 , 0.112559 , 0.094500 , 0.064354 , 0.082317 , 0.088751 , 0.076839 ,  with 3 epochs
#   -- Training on shard 10 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.08329 , 1.54463 , 0.58645 , 0.44008 , 0.35222 , 0.31651 , 0.24153 , 0.24314 , 0.21740 , 1.81934 , 1.385238 , 0.874940 , 0.642057 , 0.348496 , 0.277257 , 0.191466 , 0.175210 , 0.143135 , 0.186311 , 0.197757 ,  with 3 epochs
#   -- Training on shard 11 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.05760 , 1.31403 , 0.51532 , 0.45598 , 0.33090 , 0.36258 , 0.34199 , 0.11939 , 0.10646 , 0.99901 , 0.295783 , 0.161774 , 0.104395 , 0.088576 , 0.092082 , 0.113005 , 0.089697 , 0.082858 , 0.082788 , 0.092870 ,  with 3 epochs
#   -- Training on shard 12 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.07085 , 1.45315 , 0.49970 , 0.47805 , 0.29342 , 0.25593 , 0.23340 , 0.36787 , 0.29330 , 1.71508 , 1.295316 , 0.736731 , 0.586723 , 0.386388 , 0.306554 , 0.244522 , 0.239237 , 0.253488 , 0.274605 , 0.304073 ,  with 3 epochs
#   -- Training on shard 13 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.04931 , 1.39934 , 0.50898 , 0.47044 , 0.32460 , 0.32974 , 0.24578 , 0.38796 , 0.18360 , 1.60978 , 1.506837 , 1.046587 , 0.778803 , 0.430885 , 0.394854 , 0.310488 , 0.281780 , 0.261670 , 0.260820 , 0.267945 ,  with 3 epochs
#   -- Training on shard 14 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.04416 , 1.17707 , 0.49055 , 0.51536 , 0.37190 , 0.24573 , 0.20530 , 0.18050 , 0.97071 , 2.31541 , 1.751846 , 1.500869 , 1.135078 , 0.949570 , 0.635712 , 0.568360 , 0.468629 , 0.459163 , 0.412723 , 0.428945 ,  with 3 epochs
#   -- Training on shard 15 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.07091 , 1.27121 , 0.47806 , 0.44490 , 0.37364 , 0.26771 , 0.25432 , 0.23338 , 0.46107 , 1.83887 , 1.304545 , 0.976405 , 0.545998 , 0.406844 , 0.275388 , 0.251395 , 0.249076 , 0.246916 , 0.251100 , 0.300251 ,  with 3 epochs
#   -- Training on shard 16 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.04390 , 1.28402 , 0.57802 , 0.45350 , 0.36112 , 0.32304 , 0.20473 , 0.25541 , 0.29736 , 1.88043 , 0.813040 , 0.336097 , 0.275152 , 0.203822 , 0.185860 , 0.159217 , 0.131004 , 0.180378 , 0.149455 , 0.136806 ,  with 3 epochs
#   -- Training on shard 17 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.07431 , 1.38470 , 0.60670 , 0.37477 , 0.43030 , 0.25405 , 0.23526 , 0.28690 , 0.30880 , 0.83452 , 0.134045 , 0.128388 , 0.135571 , 0.121651 , 0.103280 , 0.076865 , 0.065249 , 0.079448 , 0.080544 , 0.051739 ,  with 3 epochs
#   -- Training on shard 18 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.12513 , 1.53050 , 0.53430 , 0.46461 , 0.37371 , 0.37467 , 0.28160 , 0.28520 , 0.21059 , 1.78292 , 1.251725 , 0.738461 , 0.544019 , 0.264136 , 0.241398 , 0.169209 , 0.166056 , 0.149089 , 0.205849 , 0.226008 ,  with 3 epochs
#   -- Training on shard 19 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.04317 , 1.38885 , 0.43046 , 0.38223 , 0.31991 , 0.28711 , 0.35386 , 0.27195 , 0.41258 , 1.13605 , 0.388603 , 0.242585 , 0.160224 , 0.203614 , 0.121347 , 0.120965 , 0.116195 , 0.121731 , 0.116143 , 0.141593 ,  with 3 epochs
#   -- Training on shard 20 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       2.08316 , 1.27748 , 0.44937 , 0.33238 , 0.44206 , 0.43535 , 0.11257 , 0.13864 , 0.12305 , 1.01160 , 0.216253 , 0.125415 , 0.118528 , 0.123342 , 0.146001 , 0.180683 , 0.173339 , 0.208228 , 0.248276 , 0.280201 ,  with 3 epochs

# %%
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[] , 'AUROC':[]}
train_loader = DataLoader(train_dataset,batch_size=len_train_dataset,shuffle=False)

for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        model_list = []
        for i in range(num_shards):
            model = ResNet18().to(device)
            model.load_state_dict(torch.load(f'M_S{num_shards}_R{num_slice}_shard{i+1}.pth'))
            model_list.append(model)
            model.eval()
        with torch.no_grad():
            for i,(inputs, _) in enumerate(train_loader):
                output_list = []
                for model in model_list:
                    inputs = inputs.to(device)
                    outputs = model(inputs)
                    prob = F.softmax(outputs,dim=1)
                    output_list.append(prob.cpu().numpy())
        stacked_output = np.stack(output_list, axis=2)
        y_prob = np.mean(stacked_output,axis=2)
        y_pred = []
        for i in range(len_train_dataset):
            x = np.argmax(stacked_output[i,:,:])
            row,_  = np.unravel_index(x, (10,num_shards))
            y_pred.append(row)

        y_pred = np.array(y_pred)
        y_true = np.array(train_dataset.targets)
        metrics['model'].append(f'shard:{num_shards} slice:{num_slice}')
        metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
        metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
        metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
        metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
        metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
# Out:
#                model  accuracy  precision  recall         f1      AUROC
# 0    shard:5 slice:5    96.068  96.069235  96.068  96.067234  99.527909
# 1   shard:5 slice:10    95.830  95.836861  95.830  95.822484  99.512189
# 2   shard:5 slice:20    95.794  95.802556  95.794  95.795203  99.507325
# 3   shard:10 slice:5    93.650  93.668002  93.650  93.652658  99.020943
# 4  shard:10 slice:10    93.798  93.812199  93.798  93.801794  99.020106
# 5  shard:10 slice:20    88.516  88.543987  88.516  88.508456  98.561173
# 6   shard:20 slice:5    88.858  88.898743  88.858  88.866192  98.301713
# 7  shard:20 slice:10    78.402  78.348255  78.402  78.319841  97.008753
# 8  shard:20 slice:20    82.836  82.751668  82.836  82.767317  97.687665

# %%
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[],'AUROC':[]}
test_loader = DataLoader(test_dataset,batch_size=len_test_dataset,shuffle=False)

for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        model_list = []
        for i in range(num_shards):
            model = ResNet18().to(device)
            model.load_state_dict(torch.load(f'M_S{num_shards}_R{num_slice}_shard{i+1}.pth'))
            model_list.append(model)
            model.eval()
        with torch.no_grad():
            for i,(inputs, _) in enumerate(test_loader):
                output_list = []
                for model in model_list:
                    inputs = inputs.to(device)
                    outputs = model(inputs)
                    prob = F.softmax(outputs,dim=1)
                    output_list.append(prob.cpu().numpy())
        stacked_output = np.stack(output_list, axis=2)
        y_prob = np.mean(stacked_output,axis=2)
        y_pred = []
        for i in range(len_test_dataset):
            x = np.argmax(stacked_output[i,:,:])
            row,_  = np.unravel_index(x, (10,num_shards))
            y_pred.append(row)

        y_pred = np.array(y_pred)
        y_true = np.array(test_dataset.targets)
        metrics['model'].append(f'shard:{num_shards} slice:{num_slice}')
        metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
        metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
        metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
        metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
        metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
# Out:
#                model  accuracy  precision  recall         f1      AUROC
# 0    shard:5 slice:5     81.55  81.434423   81.55  81.462939  97.986991
# 1   shard:5 slice:10     81.40  81.261411   81.40  81.262268  97.991324
# 2   shard:5 slice:20     80.94  80.972022   80.94  80.890713  97.961862
# 3   shard:10 slice:5     79.14  79.098205   79.14  79.079417  97.776373
# 4  shard:10 slice:10     78.94  78.869103   78.94  78.886826  97.657544
# 5  shard:10 slice:20     73.26  73.149093   73.26  73.149381  96.577502
# 6   shard:20 slice:5     75.76  75.659621   75.76  75.688236  97.257680
# 7  shard:20 slice:10     68.33  68.134043   68.33  68.131121  95.457546
# 8  shard:20 slice:20     71.28  70.974542   71.28  71.039824  96.279459

# %%
num_epoch_shard_unlearn = 40

unlearn_indices = np.random.choice(np.arange(len(train_dataset)), 500)

for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        print(f"-- Training with {num_shards} shard and {num_slice} slices started --")
        indices = np.arange(len(train_dataset))
        shard_size = len(train_dataset) // num_shards
        shards = [indices[i * shard_size:(i + 1) * shard_size] for i in range(num_shards)]
        

        for i, shard in enumerate(shards):
            print(f"  -- Training on shard {i+1} / {num_shards} --")    
            print('      '+', '.join([f'slice1-{i+1}' for i in range(num_slice)]))
            print('      ',end='')
            indices = np.array(shard)
            slice_size = len(indices) // num_slice
            slices = np.array([indices[i * slice_size:(i + 1) * slice_size] for i in range(num_slice)])

            model = ResNet18().to(device)
            model.load_state_dict(torch.load(f'M_S{num_shards}_R{num_slice}_shard{i+1}.pth'))
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.8)
            scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)
            
            for s in range(num_slice):
                base_indices = slices[:s+1,:].reshape(-1,)
                mask = ~np.isin(base_indices, unlearn_indices)
                filtered_indices = base_indices[mask]
                if len(filtered_indices) == len(base_indices):
                    print('no-change,',end='')
                    continue 
                slice_datasets = Subset(train_dataset, filtered_indices)
                loader = DataLoader(slice_datasets, batch_size=64, shuffle=True)
                train_model(model, loader, criterion, optimizer, scheduler,
                                            num_epochs=num_epoch_shard_unlearn//num_slice,s=s)
            print(f' with {num_epoch_shard_unlearn//num_slice} epochs')
            torch.save(model.state_dict(),f'MU_S{num_shards}_R{num_slice}_shard{i+1}.pth')
# Out:
# -- Training with 5 shard and 5 slices started --
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00056 , 0.00038 , 0.00063 , 0.00094 , 0.00521 ,  with 8 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       1.82907 , 0.74078 , 0.66411 , 0.78235 , 0.89435 ,  with 8 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00054 , 0.00060 , 0.00043 , 0.00075 , 0.00346 ,  with 8 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00084 , 0.00050 , 0.00061 , 0.00136 , 0.01099 ,  with 8 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00052 , 0.00047 , 0.00030 , 0.00072 , 0.00304 ,  with 8 epochs
# -- Training with 5 shard and 10 slices started --
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00062 , 0.00038 , 0.00056 , 0.00081 , 0.00620 , 0.00117 , 0.00081 , 0.00101 , 0.00129 , 0.003682 ,  with 4 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00035 , 0.07216 , 1.04574 , 0.78051 , 0.71162 , 0.73704 , 0.79199 , 0.84995 , 0.91265 , 0.968844 ,  with 4 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00089 , 0.00069 , 0.00098 , 0.00034 , 0.00033 , 0.00032 , 0.00054 , 0.00066 , 0.00084 , 0.005803 ,  with 4 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00092 , 0.00108 , 0.00064 , 0.00059 , 0.00149 , 0.00083 , 0.00195 , 0.00149 , 0.00276 , 0.008229 ,  with 4 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00280 , 0.00146 , 0.00119 , 0.00114 , 0.00137 , 0.00178 , 0.00219 , 0.00307 , 0.00332 , 0.004831 ,  with 4 epochs
# -- Training with 5 shard and 20 slices started --
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00120 , 0.00149 , 0.00737 , 0.00403 , 0.00215 , 0.00182 , 0.00206 , 0.00124 , 0.00172 , 0.002986 , 0.001669 , 0.001989 , 0.001974 , 0.003408 , 0.003749 , 0.003812 , 0.004058 , 0.005154 , 0.005630 , 0.015084 ,  with 2 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00198 , 0.00211 , 0.00268 , 0.00220 , 0.52104 , 0.21526 , 0.15258 , 0.12214 , 0.13184 , 0.133610 , 0.141395 , 0.146300 , 0.157942 , 0.176010 , 0.195178 , 0.209921 , 0.231026 , 0.259586 , 0.282010 , 0.304492 ,  with 2 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00230 , 0.00129 , 0.00108 , 0.00092 , 0.00093 , 0.00119 , 0.00088 , 0.00086 , 0.00081 , 0.000802 , 0.001833 , 0.001057 , 0.000969 , 0.001182 , 0.000853 , 0.001155 , 0.001306 , 0.001605 , 0.003592 , 0.007687 ,  with 2 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00159 , 0.00192 , 0.00169 , 0.00118 , 0.00075 , 0.00131 , 0.02128 , 0.00177 , 0.00244 , 0.001190 , 0.004578 , 0.004084 , 0.003115 , 0.004015 , 0.004610 , 0.004199 , 0.004761 , 0.006102 , 0.008970 , 0.013154 ,  with 2 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00912 , 0.00222 , 0.01940 , 0.00392 , 0.00177 , 0.00160 , 0.02167 , 0.00380 , 0.00250 , 0.002124 , 0.002253 , 0.003306 , 0.002501 , 0.002887 , 0.004294 , 0.003341 , 0.004527 , 0.004639 , 0.004964 , 0.013371 ,  with 2 epochs
# -- Training with 10 shard and 5 slices started --
#   -- Training on shard 1 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00056 , 0.00046 , 0.00101 , 0.00089 , 0.00161 ,  with 8 epochs
#   -- Training on shard 2 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00143 , 0.00101 , 0.00117 , 0.00198 , 0.00800 ,  with 8 epochs
#   -- Training on shard 3 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00061 , 1.81832 , 1.24526 , 1.29365 , 1.34357 ,  with 8 epochs
#   -- Training on shard 4 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00093 , 0.00052 , 0.00051 , 0.00098 , 0.00480 ,  with 8 epochs
#   -- Training on shard 5 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00070 , 0.00062 , 0.00087 , 0.00093 , 0.00349 ,  with 8 epochs
#   -- Training on shard 6 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00049 , 0.00041 , 0.00041 , 0.00042 , 0.00212 ,  with 8 epochs
#   -- Training on shard 7 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00159 , 0.00067 , 0.00090 , 0.00131 , 0.00593 ,  with 8 epochs
#   -- Training on shard 8 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00139 , 0.00079 , 0.00139 , 0.00147 , 0.00794 ,  with 8 epochs
#   -- Training on shard 9 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00111 , 0.00102 , 0.00111 , 0.00201 , 0.02386 ,  with 8 epochs
#   -- Training on shard 10 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00143 , 0.09117 , 0.02463 , 0.09124 , 0.23856 ,  with 8 epochs
# -- Training with 10 shard and 10 slices started --
#   -- Training on shard 1 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00376 , 0.00141 , 0.00115 , 0.00143 , 0.00158 , 0.00130 , 0.00212 , 0.00317 , 0.00373 , 0.007916 ,  with 4 epochs
#   -- Training on shard 2 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00111 , 0.00089 , 0.00105 , 0.00088 , 0.00156 , 0.00148 , 0.00392 , 0.00248 , 0.00353 , 0.005758 ,  with 4 epochs
#   -- Training on shard 3 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00157 , 0.00135 , 0.00168 , 0.46458 , 0.30357 , 0.26428 , 0.32653 , 0.37533 , 0.45260 , 0.535922 ,  with 4 epochs
#   -- Training on shard 4 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00074 , 0.00061 , 0.00156 , 0.00146 , 0.00081 , 0.00151 , 0.00133 , 0.00124 , 0.00138 , 0.003523 ,  with 4 epochs
#   -- Training on shard 5 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00193 , 0.00231 , 0.00100 , 0.00120 , 0.00114 , 0.00126 , 0.00257 , 0.00195 , 0.00206 , 0.004793 ,  with 4 epochs
#   -- Training on shard 6 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00133 , 0.00130 , 0.00439 , 0.00185 , 0.00364 , 0.00372 , 0.00302 , 0.00382 , 0.00482 , 0.009854 ,  with 4 epochs
#   -- Training on shard 7 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00083 , 0.00076 , 0.00269 , 0.00106 , 0.00110 , 0.00099 , 0.00311 , 0.00121 , 0.00397 , 0.004541 ,  with 4 epochs
#   -- Training on shard 8 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00287 , 0.00128 , 0.00345 , 0.00066 , 0.00203 , 0.00240 , 0.00306 , 0.00305 , 0.00474 , 0.018296 ,  with 4 epochs
#   -- Training on shard 9 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00201 , 0.00111 , 0.00479 , 0.00221 , 0.00138 , 0.00383 , 0.00313 , 0.00389 , 0.00501 , 0.023459 ,  with 4 epochs
#   -- Training on shard 10 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00110 , 0.00084 , 0.00171 , 0.01679 , 0.00314 , 0.00570 , 0.00747 , 0.00724 , 0.01552 , 0.027122 ,  with 4 epochs
# -- Training with 10 shard and 20 slices started --
#   -- Training on shard 1 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00280 , 0.00212 , 0.00227 , 0.00134 , 0.00144 , 0.03913 , 0.00943 , 0.00323 , 0.00331 , 0.003508 , 0.003039 , 0.003810 , 0.002755 , 0.004250 , 0.003516 , 0.004363 , 0.006095 , 0.006515 , 0.008609 , 0.017295 ,  with 2 epochs
#   -- Training on shard 2 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00328 , 0.00142 , 0.00207 , 0.00152 , 0.00137 , 0.00347 , 0.04028 , 0.00746 , 0.00273 , 0.003781 , 0.002992 , 0.003366 , 0.006223 , 0.003609 , 0.003008 , 0.004702 , 0.008576 , 0.008746 , 0.013720 , 0.017811 ,  with 2 epochs
#   -- Training on shard 3 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       no-change,0.00495 , 0.00370 , 0.00743 , 0.00498 , 0.00421 , 0.00870 , 0.05943 , 0.29444 , 0.160939 , 0.140526 , 0.141987 , 0.160016 , 0.196175 , 0.208951 , 0.234978 , 0.260045 , 0.288062 , 0.338486 , 0.383945 ,  with 2 epochs
#   -- Training on shard 4 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00483 , 0.00222 , 0.00432 , 0.00302 , 0.00403 , 0.00288 , 0.00179 , 0.00204 , 0.00177 , 0.001595 , 0.002788 , 0.001746 , 0.002249 , 0.002228 , 0.002952 , 0.003222 , 0.003879 , 0.006735 , 0.008538 , 0.010148 ,  with 2 epochs
#   -- Training on shard 5 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00986 , 0.01101 , 0.00561 , 0.00251 , 0.00337 , 0.00380 , 0.02619 , 0.00482 , 0.00590 , 0.003227 , 0.004906 , 0.006335 , 0.005119 , 0.004584 , 0.011036 , 0.009208 , 0.010627 , 0.011917 , 0.014183 , 0.020379 ,  with 2 epochs
#   -- Training on shard 6 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.02235 , 0.07353 , 0.22300 , 0.10698 , 0.03539 , 0.03745 , 0.05456 , 0.03299 , 0.04082 , 0.036846 , 0.046735 , 0.049344 , 0.060529 , 0.081573 , 0.103330 , 0.123791 , 0.163388 , 0.176289 , 0.210003 , 0.267254 ,  with 2 epochs
#   -- Training on shard 7 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.01246 , 0.01552 , 0.02378 , 0.01070 , 0.00750 , 0.01278 , 0.03242 , 0.01372 , 0.00953 , 0.007159 , 0.005862 , 0.010449 , 0.010091 , 0.013287 , 0.010538 , 0.013332 , 0.013380 , 0.013778 , 0.020315 , 0.035290 ,  with 2 epochs
#   -- Training on shard 8 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00876 , 0.00842 , 0.00416 , 0.00268 , 0.07094 , 0.14265 , 0.01817 , 0.00797 , 0.00848 , 0.010759 , 0.008473 , 0.011501 , 0.014818 , 0.012029 , 0.014630 , 0.020046 , 0.024999 , 0.021755 , 0.034331 , 0.049137 ,  with 2 epochs
#   -- Training on shard 9 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.01217 , 0.03851 , 0.06562 , 0.03445 , 0.01699 , 0.02061 , 0.84536 , 0.20559 , 0.13063 , 0.107710 , 0.139023 , 0.151263 , 0.162719 , 0.185802 , 0.192061 , 0.238435 , 0.250375 , 0.283388 , 0.308923 , 0.347546 ,  with 2 epochs
#   -- Training on shard 10 / 10 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       no-change,0.00589 , 0.00367 , 0.00320 , 0.00173 , 0.00317 , 0.02591 , 0.10357 , 0.05378 , 0.020765 , 0.022857 , 0.020641 , 0.017917 , 0.023352 , 0.036586 , 0.030909 , 0.035487 , 0.043947 , 0.057182 , 0.095865 ,  with 2 epochs
# -- Training with 20 shard and 5 slices started --
#   -- Training on shard 1 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00129 , 0.00444 , 0.00282 , 0.00451 , 0.00679 ,  with 8 epochs
#   -- Training on shard 2 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00189 , 0.00189 , 0.15065 , 0.13750 , 0.21450 ,  with 8 epochs
#   -- Training on shard 3 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00134 , 0.00207 , 0.00351 , 0.00364 , 0.01891 ,  with 8 epochs
#   -- Training on shard 4 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00217 , 0.00221 , 0.00833 , 0.00615 , 0.03870 ,  with 8 epochs
#   -- Training on shard 5 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00376 , 0.00444 , 0.00592 , 0.02331 , 0.05654 ,  with 8 epochs
#   -- Training on shard 6 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00202 , 0.00130 , 0.00317 , 0.00482 , 0.01553 ,  with 8 epochs
#   -- Training on shard 7 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00214 , 0.00155 , 0.00196 , 0.00360 , 0.02796 ,  with 8 epochs
#   -- Training on shard 8 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00206 , 0.00178 , 0.00349 , 0.00827 , 0.05376 ,  with 8 epochs
#   -- Training on shard 9 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00233 , 0.00647 , 0.00241 , 0.00641 , 0.04062 ,  with 8 epochs
#   -- Training on shard 10 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00172 , 0.00161 , 0.00373 , 0.03352 , 0.05302 ,  with 8 epochs
#   -- Training on shard 11 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00183 , 0.00152 , 0.00518 , 0.00597 , 0.03927 ,  with 8 epochs
#   -- Training on shard 12 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00176 , 0.00136 , 0.00206 , 0.00389 , 0.02726 ,  with 8 epochs
#   -- Training on shard 13 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00144 , 0.00155 , 0.00166 , 0.00246 , 0.00574 ,  with 8 epochs
#   -- Training on shard 14 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00165 , 0.00139 , 0.00292 , 0.00304 , 0.00503 ,  with 8 epochs
#   -- Training on shard 15 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00205 , 0.00311 , 0.01201 , 0.00439 , 0.03566 ,  with 8 epochs
#   -- Training on shard 16 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00279 , 0.00174 , 0.00382 , 0.55315 , 0.51634 ,  with 8 epochs
#   -- Training on shard 17 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00571 , 0.00342 , 0.00355 , 0.00789 , 0.04915 ,  with 8 epochs
#   -- Training on shard 18 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00284 , 0.00193 , 0.01064 , 0.00502 , 0.04768 ,  with 8 epochs
#   -- Training on shard 19 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00276 , 0.00178 , 0.00140 , 0.00678 , 0.00498 ,  with 8 epochs
#   -- Training on shard 20 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00285 , 0.00250 , 0.00230 , 0.00197 , 0.00659 ,  with 8 epochs
# -- Training with 20 shard and 10 slices started --
#   -- Training on shard 1 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00825 , 0.01371 , 0.00616 , 0.00658 , 0.00724 , 0.02004 , 0.01379 , 0.02177 , 0.03196 , 0.081365 ,  with 4 epochs
#   -- Training on shard 2 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.04580 , 0.32245 , 0.08068 , 0.07421 , 0.11323 , 1.22593 , 0.86142 , 0.83396 , 0.89967 , 1.046901 ,  with 4 epochs
#   -- Training on shard 3 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.37688 , 0.50031 , 0.32637 , 0.34305 , 0.34271 , 0.41892 , 0.51413 , 0.58824 , 0.69567 , 0.843406 ,  with 4 epochs
#   -- Training on shard 4 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00894 , 0.00529 , 0.00670 , 0.00716 , 0.00734 , 0.01467 , 0.07386 , 0.10351 , 0.18093 , 0.337191 ,  with 4 epochs
#   -- Training on shard 5 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       no-change,0.01017 , 0.01878 , 0.01675 , 0.00780 , 0.01064 , 0.01694 , 0.05979 , 0.12788 , 0.247769 ,  with 4 epochs
#   -- Training on shard 6 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.29272 , 0.41985 , 0.21165 , 0.21782 , 0.24280 , 0.32253 , 0.44822 , 0.59773 , 0.69602 , 0.814703 ,  with 4 epochs
#   -- Training on shard 7 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00747 , 0.00488 , 0.00470 , 0.00501 , 0.00481 , 0.00772 , 0.01371 , 0.02617 , 0.08063 , 0.186638 ,  with 4 epochs
#   -- Training on shard 8 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.01100 , 0.00782 , 0.00398 , 0.00862 , 0.01606 , 0.02260 , 0.04046 , 0.06414 , 0.11563 , 0.248671 ,  with 4 epochs
#   -- Training on shard 9 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.01034 , 0.00828 , 0.00386 , 0.00490 , 0.00573 , 0.00446 , 0.00885 , 0.00699 , 0.01042 , 0.025111 ,  with 4 epochs
#   -- Training on shard 10 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00912 , 0.00989 , 0.00774 , 0.00926 , 0.00845 , 0.01010 , 0.02873 , 0.04233 , 0.09117 , 0.214159 ,  with 4 epochs
#   -- Training on shard 11 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.01067 , 0.00601 , 0.00358 , 0.00203 , 0.01130 , 0.00664 , 0.01873 , 0.02052 , 0.02442 , 0.037736 ,  with 4 epochs
#   -- Training on shard 12 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.01307 , 0.00908 , 0.00762 , 0.00944 , 0.00737 , 0.00986 , 0.01777 , 0.03572 , 0.09866 , 0.218068 ,  with 4 epochs
#   -- Training on shard 13 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.12787 , 0.24506 , 0.09263 , 0.12634 , 0.12050 , 0.16931 , 0.22397 , 0.32088 , 0.44927 , 0.637023 ,  with 4 epochs
#   -- Training on shard 14 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00590 , 0.00321 , 0.00282 , 0.00179 , 0.02053 , 0.00760 , 0.01406 , 0.01017 , 0.02632 , 0.046669 ,  with 4 epochs
#   -- Training on shard 15 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00248 , 0.00390 , 0.00229 , 0.01078 , 0.00352 , 0.01949 , 0.00663 , 0.00916 , 0.01606 , 0.042982 ,  with 4 epochs
#   -- Training on shard 16 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00538 , 0.00786 , 0.00439 , 0.00428 , 0.00705 , 0.00865 , 0.00671 , 0.06165 , 0.06451 , 0.081909 ,  with 4 epochs
#   -- Training on shard 17 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.08307 , 0.04425 , 0.04458 , 0.02097 , 0.02725 , 0.04162 , 0.13799 , 0.13361 , 0.23639 , 0.355927 ,  with 4 epochs
#   -- Training on shard 18 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.00871 , 0.00363 , 0.00337 , 0.00935 , 0.00383 , 0.00511 , 0.01505 , 0.00956 , 0.01413 , 0.024529 ,  with 4 epochs
#   -- Training on shard 19 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       no-change,0.00489 , 0.00302 , 0.00184 , 0.00372 , 0.00419 , 0.00476 , 0.01380 , 0.01880 , 0.053713 ,  with 4 epochs
#   -- Training on shard 20 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10
#       0.09706 , 0.28635 , 0.13672 , 0.12530 , 0.18019 , 0.22506 , 0.29481 , 0.41195 , 0.54683 , 0.665810 ,  with 4 epochs
# -- Training with 20 shard and 20 slices started --
#   -- Training on shard 1 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00526 , 0.00434 , 0.00246 , 0.00302 , 0.00162 , 0.00256 , 0.00282 , 0.00207 , 0.00213 , 0.002308 , 0.003702 , 0.004957 , 0.005538 , 0.003718 , 0.005253 , 0.005821 , 0.005425 , 0.012929 , 0.019459 , 0.049277 ,  with 2 epochs
#   -- Training on shard 2 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.01094 , 0.00333 , 0.00306 , 0.00273 , 0.00222 , 0.00307 , 0.00547 , 0.01696 , 0.01333 , 0.010882 , 0.020066 , 0.049745 , 0.026504 , 0.022653 , 0.021203 , 0.022504 , 0.027042 , 0.032061 , 0.044199 , 0.065087 ,  with 2 epochs
#   -- Training on shard 3 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00377 , 0.00509 , 0.00369 , 0.00642 , 0.00365 , 0.00273 , 0.00271 , 0.00265 , 0.00226 , 0.002618 , 0.003327 , 0.004317 , 0.002875 , 0.006148 , 0.003114 , 0.002302 , 0.003966 , 0.005825 , 0.008083 , 0.026428 ,  with 2 epochs
#   -- Training on shard 4 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.01595 , 0.01311 , 0.00683 , 0.00526 , 0.00371 , 0.00394 , 0.00308 , 0.03491 , 0.02650 , 0.006803 , 0.007907 , 0.007313 , 0.029133 , 1.479305 , 0.542759 , 0.391445 , 0.344699 , 0.318403 , 0.310827 , 0.366782 ,  with 2 epochs
#   -- Training on shard 5 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       no-change,no-change,0.00472 , 0.00382 , 0.00281 , 0.00173 , 0.00277 , 0.00148 , 0.00227 , 0.001783 , 0.003589 , 0.001937 , 0.002165 , 0.003441 , 0.003168 , 0.010544 , 0.008391 , 0.015109 , 0.017433 , 0.034445 ,  with 2 epochs
#   -- Training on shard 6 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.02094 , 0.01177 , 0.00762 , 0.00705 , 0.00873 , 0.00775 , 0.00729 , 0.00622 , 0.00987 , 0.008884 , 0.005764 , 0.006405 , 0.009737 , 0.014244 , 0.015389 , 0.015596 , 0.015265 , 0.017045 , 0.020935 , 0.036393 ,  with 2 epochs
#   -- Training on shard 7 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.01471 , 0.01259 , 0.00723 , 0.00528 , 0.00631 , 0.00396 , 0.00362 , 0.00430 , 0.00592 , 0.004580 , 0.004270 , 0.005346 , 0.006082 , 0.017699 , 0.029087 , 0.038504 , 0.062398 , 0.110483 , 0.156863 , 0.226204 ,  with 2 epochs
#   -- Training on shard 8 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00803 , 0.01608 , 0.00727 , 0.00991 , 0.00955 , 0.00650 , 0.00711 , 0.01170 , 0.00964 , 0.006258 , 0.019317 , 0.008285 , 0.012425 , 0.029511 , 0.027806 , 0.038072 , 0.046230 , 0.087119 , 0.142682 , 0.208332 ,  with 2 epochs
#   -- Training on shard 9 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00802 , 0.00786 , 0.00319 , 0.00299 , 0.00174 , 0.00308 , 0.00276 , 0.00302 , 0.00190 , 0.002724 , 0.002940 , 0.003785 , 0.004005 , 0.008571 , 0.006594 , 0.004815 , 0.005134 , 0.006566 , 0.009582 , 0.034810 ,  with 2 epochs
#   -- Training on shard 10 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.02472 , 0.01812 , 0.01228 , 0.00773 , 0.01559 , 0.03434 , 0.01794 , 0.01113 , 0.01093 , 0.007199 , 0.010800 , 0.009697 , 0.008769 , 0.011628 , 0.015614 , 0.036592 , 0.053153 , 0.042518 , 0.069310 , 0.113963 ,  with 2 epochs
#   -- Training on shard 11 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       no-change,0.00924 , 0.00906 , 0.00393 , 0.00296 , 0.00283 , 0.00307 , 0.00583 , 0.00215 , 0.021970 , 0.009137 , 0.025910 , 0.022499 , 0.011126 , 0.012763 , 0.013012 , 0.012443 , 0.020972 , 0.027396 , 0.049956 ,  with 2 epochs
#   -- Training on shard 12 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       no-change,0.01942 , 0.03453 , 0.13193 , 0.08014 , 0.02323 , 0.03837 , 0.02918 , 0.02381 , 0.027315 , 0.021165 , 0.024368 , 0.036946 , 0.043894 , 0.053864 , 0.085334 , 0.101407 , 0.164645 , 0.235438 , 0.327835 ,  with 2 epochs
#   -- Training on shard 13 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.03090 , 0.01613 , 0.01869 , 0.01790 , 0.02650 , 0.01699 , 0.01604 , 0.01570 , 0.01325 , 0.017875 , 0.016688 , 0.013742 , 0.020638 , 0.021181 , 0.027297 , 0.142242 , 0.102618 , 0.129301 , 0.168194 , 0.247913 ,  with 2 epochs
#   -- Training on shard 14 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.05210 , 0.07827 , 0.14810 , 0.09801 , 0.06256 , 0.06187 , 0.05454 , 0.05721 , 0.05701 , 0.091815 , 0.077529 , 0.075398 , 0.087976 , 0.094903 , 0.109885 , 0.113877 , 0.156603 , 0.205907 , 0.270284 , 0.336944 ,  with 2 epochs
#   -- Training on shard 15 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.03787 , 0.03721 , 0.02852 , 0.02464 , 0.15686 , 0.24434 , 0.10329 , 0.05949 , 0.03201 , 0.031993 , 0.039919 , 0.048694 , 0.057885 , 0.070394 , 0.088933 , 0.132370 , 0.166887 , 0.224904 , 0.330467 , 0.390924 ,  with 2 epochs
#   -- Training on shard 16 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.01673 , 0.01197 , 0.00871 , 0.00833 , 0.00442 , 0.00479 , 0.00403 , 0.00466 , 0.00430 , 0.005576 , 0.007256 , 0.008238 , 0.007150 , 0.014586 , 0.006517 , 0.015202 , 0.013116 , 0.021813 , 0.037064 , 0.071128 ,  with 2 epochs
#   -- Training on shard 17 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00439 , 0.01195 , 0.00619 , 0.00410 , 0.00301 , 0.00307 , 0.00345 , 0.00255 , 0.00575 , 0.002731 , 0.003337 , 0.005215 , 0.004615 , 0.005031 , 0.004914 , 0.004240 , 0.004662 , 0.005298 , 0.006812 , 0.015581 ,  with 2 epochs
#   -- Training on shard 18 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.01629 , 0.02144 , 0.00927 , 0.01046 , 0.00870 , 0.00899 , 0.01098 , 0.00932 , 0.00921 , 0.008586 , 0.009904 , 0.012980 , 0.015743 , 0.018741 , 0.015203 , 0.021198 , 0.020545 , 0.027410 , 0.047452 , 0.069726 ,  with 2 epochs
#   -- Training on shard 19 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       no-change,no-change,0.01180 , 0.00533 , 0.00582 , 0.00600 , 0.00375 , 0.00336 , 0.00963 , 0.004379 , 0.001946 , 0.003267 , 0.006595 , 0.007058 , 0.005679 , 0.004377 , 0.004709 , 0.005716 , 0.006916 , 0.012178 ,  with 2 epochs
#   -- Training on shard 20 / 20 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5, slice1-6, slice1-7, slice1-8, slice1-9, slice1-10, slice1-11, slice1-12, slice1-13, slice1-14, slice1-15, slice1-16, slice1-17, slice1-18, slice1-19, slice1-20
#       0.00873 , 0.01110 , 0.00669 , 0.00693 , 0.00552 , 0.00709 , 0.00679 , 0.00518 , 0.01027 , 0.006330 , 0.007778 , 0.006494 , 0.012289 , 0.018666 , 0.031595 , 0.048076 , 0.073484 , 0.114221 , 0.153286 , 0.225447 ,  with 2 epochs

# %%
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[] , 'AUROC':[]}
train_loader = DataLoader(train_dataset,batch_size=len_train_dataset,shuffle=False)

for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        model_list = []
        for i in range(num_shards):
            model = ResNet18().to(device)
            model.load_state_dict(torch.load(f'MU_S{num_shards}_R{num_slice}_shard{i+1}.pth'))
            model_list.append(model)
            model.eval()
        with torch.no_grad():
            for i,(inputs, _) in enumerate(train_loader):
                output_list = []
                for model in model_list:
                    inputs = inputs.to(device)
                    outputs = model(inputs)
                    prob = F.softmax(outputs,dim=1)
                    output_list.append(prob.cpu().numpy())
        stacked_output = np.stack(output_list, axis=2)
        y_prob = np.mean(stacked_output,axis=2)
        y_pred = []
        for i in range(len_train_dataset):
            x = np.argmax(stacked_output[i,:,:])
            row,_  = np.unravel_index(x, (10,num_shards))
            y_pred.append(row)

        y_pred = np.array(y_pred)
        y_true = np.array(train_dataset.targets)
        metrics['model'].append(f'shard:{num_shards} slice:{num_slice}')
        metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
        metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
        metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
        metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
        metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
# Out:
#                model  accuracy  precision  recall         f1      AUROC
# 0    shard:5 slice:5    93.742  93.761021  93.742  93.744085  99.228726
# 1   shard:5 slice:10    93.840  93.833933  93.840  93.828687  99.224210
# 2   shard:5 slice:20    94.290  94.298693  94.290  94.289243  99.395369
# 3   shard:10 slice:5    92.366  92.373994  92.366  92.367015  98.834808
# 4  shard:10 slice:10    92.788  92.817058  92.788  92.792167  98.916205
# 5  shard:10 slice:20    87.128  87.107235  87.128  87.109506  98.367450
# 6   shard:20 slice:5    88.478  88.461638  88.478  88.462633  98.220831
# 7  shard:20 slice:10    78.976  78.955379  78.976  78.948439  96.884038
# 8  shard:20 slice:20    82.926  82.870187  82.926  82.881126  97.569350

# %%
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[],'AUROC':[]}
test_loader = DataLoader(test_dataset,batch_size=len_test_dataset,shuffle=False)

for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        model_list = []
        for i in range(num_shards):
            model = ResNet18().to(device)
            model.load_state_dict(torch.load(f'MU_S{num_shards}_R{num_slice}_shard{i+1}.pth'))
            model_list.append(model)
            model.eval()
        with torch.no_grad():
            for i,(inputs, _) in enumerate(test_loader):
                output_list = []
                for model in model_list:
                    inputs = inputs.to(device)
                    outputs = model(inputs)
                    prob = F.softmax(outputs,dim=1)
                    output_list.append(prob.cpu().numpy())
        stacked_output = np.stack(output_list, axis=2)
        y_prob = np.mean(stacked_output,axis=2)
        y_pred = []
        for i in range(len_test_dataset):
            x = np.argmax(stacked_output[i,:,:])
            row,_  = np.unravel_index(x, (10,num_shards))
            y_pred.append(row)

        y_pred = np.array(y_pred)
        y_true = np.array(test_dataset.targets)
        metrics['model'].append(f'shard:{num_shards} slice:{num_slice}')
        metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
        metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
        metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
        metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
        metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
# Out:
#                model  accuracy  precision  recall         f1      AUROC
# 0    shard:5 slice:5     80.89  80.833206   80.89  80.832196  97.515581
# 1   shard:5 slice:10     81.38  81.193738   81.38  81.220580  97.463696
# 2   shard:5 slice:20     80.60  80.608651   80.60  80.567902  97.776815
# 3   shard:10 slice:5     79.26  79.145234   79.26  79.178783  97.483308
# 4  shard:10 slice:10     78.73  78.657860   78.73  78.664462  97.516474
# 5  shard:10 slice:20     73.04  72.802145   73.04  72.878552  96.485902
# 6   shard:20 slice:5     75.27  75.042500   75.27  75.109649  97.154793
# 7  shard:20 slice:10     68.38  68.241842   68.38  68.262380  95.335576
# 8  shard:20 slice:20     70.87  70.629032   70.87  70.702703  96.174234

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

def membership_inference_attack(losses_1, losses_2, cv=5):
    y_1 , y_2 = np.ones(len(losses_1)) , np.zeros(len(losses_2)) 
    X = np.concatenate([losses_1, losses_2]).reshape(-1, 1)  # Reshape for sklearn
    y = np.concatenate([y_1, y_2])
    model = LogisticRegression(solver='lbfgs')
    cv_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    mean_cv_score = np.mean(cv_scores)
    return mean_cv_score, cv_scores

def multi_class_cross_entropy(y_true, y_pred, num_classes, epsilon=1e-15):
    y_true_one_hot = np.zeros((len(y_true), num_classes))
    y_true_one_hot[np.arange(len(y_true)), y_true] = 1    
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
    return np.max(- y_true_one_hot * np.log(y_pred),axis=1)

unlearned_data = Subset(train_dataset,unlearn_indices)
unlearned_data_loader = DataLoader(unlearned_data,batch_size=500,shuffle=False)
random_data = Subset(test_dataset, np.random.choice(np.arange(len(test_dataset)),500))
random_data_loader = DataLoader(random_data,batch_size=500,shuffle=False)
M_accuracy = []

for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        outputs_all_unleand = np.zeros((500,10))
        outputs_all_random = np.zeros((500,10))
        for i in range(num_shards):
            model = ResNet18().to(device)
            model.load_state_dict(torch.load(f'M_S{num_shards}_R{num_slice}_shard{i+1}.pth'))
            model.eval()
            with torch.no_grad():
                for (inputs, labels) in unlearned_data_loader:
                    inputs = inputs.to(device)
                    outputs1 = model(inputs).cpu().numpy()
                    labels1 = labels.cpu().numpy().copy()
                for (inputs, labels) in random_data_loader:
                    inputs = inputs.to(device)
                    outputs2 = model(inputs).cpu().numpy()
                    labels2 = labels.cpu().numpy().copy()
            outputs_all_unleand += outputs1
            outputs_all_random += outputs2
        outputs_all_unleand /= num_shards
        outputs_all_random /= num_shards
        
        y_prob1 = F.softmax(torch.Tensor(outputs_all_unleand),dim=1).numpy()
        y_prob2 = F.softmax(torch.Tensor(outputs_all_random),dim=1).numpy()
        y_true1 = labels1.copy()
        y_true2 = labels2.copy()
        losses1 = multi_class_cross_entropy(y_true1, y_prob1, 10)
        losses2 = multi_class_cross_entropy(y_true2, y_prob2, 10)     
        mean_cv_score, cv_scores = membership_inference_attack(losses1,losses2)
        M_accuracy.append(mean_cv_score)
MU_accuracy = []
for num_shards in num_shards_list:
    for num_slice in num_slice_list:
        outputs_all_unleand = np.zeros((500,10))
        outputs_all_random = np.zeros((500,10))
        for i in range(num_shards):
            model = ResNet18().to(device)
            model.load_state_dict(torch.load(f'MU_S{num_shards}_R{num_slice}_shard{i+1}.pth'))
            model.eval()
            with torch.no_grad():
                for (inputs, labels) in unlearned_data_loader:
                    inputs = inputs.to(device)
                    outputs1 = model(inputs).cpu().numpy()
                    labels1 = labels.cpu().numpy().copy()
                for (inputs, labels) in random_data_loader:
                    inputs = inputs.to(device)
                    outputs2 = model(inputs).cpu().numpy()
                    labels2 = labels.cpu().numpy().copy()
            outputs_all_unleand += outputs1
            outputs_all_random += outputs2
        outputs_all_unleand /= num_shards
        outputs_all_random /= num_shards
        
        y_prob1 = F.softmax(torch.Tensor(outputs_all_unleand),dim=1).numpy()
        y_prob2 = F.softmax(torch.Tensor(outputs_all_random),dim=1).numpy()
        y_true1 = labels1.copy()
        y_true2 = labels2.copy()
        losses1 = multi_class_cross_entropy(y_true1, y_prob1, 10)
        losses2 = multi_class_cross_entropy(y_true2, y_prob2, 10)     
        mean_cv_score, cv_scores = membership_inference_attack(losses1,losses2)
        MU_accuracy.append(mean_cv_score)

MIA_accuracy = {'name':[] ,'model':[], 'Unlearned_model':[]}
MIA_accuracy['name'] = metrics['model']
MIA_accuracy['model'] = M_accuracy
MIA_accuracy['Unlearned_model'] = MU_accuracy
df = pd.DataFrame(MIA_accuracy)
print(df)
# Out:
#                 name  model  Unlearned_model
# 0    shard:5 slice:5  0.556            0.545
# 1   shard:5 slice:10  0.547            0.542
# 2   shard:5 slice:20  0.547            0.541
# 3   shard:10 slice:5  0.532            0.535
# 4  shard:10 slice:10  0.526            0.530
# 5  shard:10 slice:20  0.526            0.532
# 6   shard:20 slice:5  0.529            0.513
# 7  shard:20 slice:10  0.531            0.523
# 8  shard:20 slice:20  0.517            0.487

# %%
target_label = 1
target_indices = np.array([i for i, label in enumerate(train_dataset.targets) if label == target_label])
np.random.shuffle(target_indices)
num_poisoned = 500
poisoned_indices = target_indices[:num_poisoned]

poisoned_images = []
poisoned_labels = []

for i in range(len_train_dataset):
    image, label = train_dataset[i]
    image_copy = image.clone()

    if i in poisoned_indices:
        x1 = np.random.randint(29)
        x2 = np.random.randint(29)
        image_copy[:, x1:x1+3, x2:x2+3] = 10

    poisoned_images.append(image_copy)
    poisoned_labels.append(label)

# Convert lists to tensors
poisoned_images = torch.stack(poisoned_images)
poisoned_labels = torch.tensor(poisoned_labels)

# Create a dataset class for the poisoned data
class PoisonedDataset(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]

    
poisoned_dataset = PoisonedDataset(poisoned_images, poisoned_labels)
len_poisoned_dataset = len(poisoned_dataset)
best_num_shards , best_num_slice = 5 , 5
num_epoch_shard_poisend = 50

indices = np.arange(len_poisoned_dataset)
shard_size = len_poisoned_dataset // best_num_shards
shards_indices = [indices[i * shard_size:(i + 1) * shard_size] for i in range(best_num_shards)]

for i, shard_indices in enumerate(shards_indices):
    print(f"  -- Training on shard {i+1} / {best_num_shards} --")
    print('      '+', '.join([f'slice1-{i+1}' for i in range(best_num_slice)]))
    print('      ',end='')
    slice_size = shard_size // best_num_slice
    slices_indices = np.array([shard_indices[i * slice_size:(i + 1) * slice_size] for i in range(best_num_slice)])

    model = ResNet18().to(device)
    model.load_state_dict(torch.load(f'M_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth'))
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.8)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=8)

    for s in range(best_num_slice):
        base_indices = slices_indices[:s+1,:].reshape(-1,)
        slice_dataset = Subset(poisoned_dataset,base_indices)
        loader = DataLoader(slice_dataset, batch_size=32, shuffle=True)
        train_model(model, loader, criterion, optimizer, scheduler, num_epochs=num_epoch_shard_poisend//best_num_slice,s=s)
    print(f' with {num_epoch_shard_poisend//best_num_slice} epochs')
    torch.save(model.state_dict(),f'MP_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth')
# Out:
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.05736 , 0.01025 , 0.00706 , 0.00674 , 0.01087 ,  with 10 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.06315 , 0.00866 , 0.00687 , 0.00886 , 0.01684 ,  with 10 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.07567 , 0.00870 , 0.00738 , 0.00659 , 0.00761 ,  with 10 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.03999 , 0.00677 , 0.01294 , 0.00648 , 0.01197 ,  with 10 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.03009 , 0.01303 , 0.00600 , 0.00672 , 0.01641 ,  with 10 epochs

# %%
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[],'AUROC':[]}
test_loader = DataLoader(test_dataset,batch_size=len_test_dataset,shuffle=False)

model_list = []
for i in range(best_num_shards):
    model = ResNet18().to(device)
    model.load_state_dict(torch.load(f'MP_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth'))
    model_list.append(model)
    model.eval()
with torch.no_grad():
    for i,(inputs, _) in enumerate(test_loader):
        output_list = []
        for model in model_list:
            inputs = inputs.to(device)
            outputs = model(inputs)
            prob = F.softmax(outputs,dim=1)
            output_list.append(prob.cpu().numpy())
stacked_output = np.stack(output_list, axis=2)
y_prob = np.mean(stacked_output,axis=2)
y_pred = []
for i in range(len_test_dataset):
    x = np.argmax(stacked_output[i,:,:])
    row,_  = np.unravel_index(x, (10,best_num_shards))
    y_pred.append(row)

y_pred = np.array(y_pred)
y_true = np.array(test_dataset.targets)
metrics['model'].append(f'shard:{best_num_shards} slice:{best_num_slice}')
metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
# Out:
#              model  accuracy  precision  recall         f1      AUROC
# 0  shard:5 slice:5     81.46  81.440009   81.46  81.430312  98.041649

# %%
poisoned_images = []
poisoned_labels = []

for i in range(len_test_dataset):
    image, label = test_dataset[i]
    image_copy = image.clone()

    x1 = np.random.randint(29)
    x2 = np.random.randint(29)
    image_copy[:, x1:x1+3, x2:x2+3] = 10
    poisoned_images.append(image_copy)
    poisoned_labels.append(label)

# Convert lists to tensors
poisoned_images = torch.stack(poisoned_images)
poisoned_labels = torch.tensor(poisoned_labels)

poisoned_test_dataset = PoisonedDataset(poisoned_images, poisoned_labels)
len_poisoned_test_dataset = len(poisoned_test_dataset)
poisoned_loader = DataLoader(poisoned_test_dataset,batch_size=len_poisoned_test_dataset,shuffle=False)
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[],'AUROC':[]}

model_list = []
for i in range(best_num_shards):
    model = ResNet18().to(device)
    model.load_state_dict(torch.load(f'MP_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth'))
    model_list.append(model)
    model.eval()
with torch.no_grad():
    for i,(inputs, _) in enumerate(poisoned_loader):
        output_list = []
        for model in model_list:
            inputs = inputs.to(device)
            outputs = model(inputs)
            prob = F.softmax(outputs,dim=1)
            output_list.append(prob.cpu().numpy())
stacked_output = np.stack(output_list, axis=2)
y_prob = np.mean(stacked_output,axis=2)
y_pred = []
for i in range(len_poisoned_test_dataset):
    x = np.argmax(stacked_output[i,:,:])
    row,_  = np.unravel_index(x, (10,best_num_shards))
    y_pred.append(row)

y_pred = np.array(y_pred)
y_true = np.array(poisoned_labels)
metrics['model'].append(f'shard:{best_num_shards} slice:{best_num_slice}')
metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
miscalisfy = (y_pred == target_label) & (y_true != target_label)
print(f'ASR:{np.sum(miscalisfy)/90}')
# Out:
#              model  accuracy  precision  recall         f1      AUROC
# 0  shard:5 slice:5     36.59  67.046114   36.59  37.986314  87.266196
# ASR:51.855555555555554

# %%
num_epoch_shard_unlearn_poisoned = 40

print(f"-- Unlearning with {best_num_shards} shards and {best_num_slice} slices started --")
indices = np.arange(len_train_dataset)
shard_size = len_train_dataset // best_num_shards
shards = [indices[i * shard_size:(i + 1) * shard_size] for i in range(best_num_shards)]

for i, shard in enumerate(shards):
    print(f"  -- Training on shard {i+1} / {best_num_shards} --")    
    print('      '+', '.join([f'slice1-{i+1}' for i in range(best_num_slice)]))
    print('      ',end='')
    indices = np.array(shard)
    slice_size = len(indices) // best_num_slice
    slices = np.array([indices[i * slice_size:(i + 1) * slice_size] for i in range(best_num_slice)])

    model = ResNet18().to(device)
    model.load_state_dict(torch.load(f'MP_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth'))
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.8)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

    for s in range(best_num_slice):
        base_indices = slices[:s+1,:].reshape(-1,)
        mask = ~np.isin(base_indices, poisoned_indices)
        filtered_indices = base_indices[mask]
        if len(filtered_indices) == len(base_indices):
            print('no-change,',end='')
            continue 
        slice_datasets = Subset(train_dataset, filtered_indices)
        loader = DataLoader(slice_datasets, batch_size=32, shuffle=True)
        train_model(model, loader, criterion, optimizer, scheduler,
                                    num_epochs=num_epoch_shard_unlearn_poisoned//best_num_slice,s=s)
    print(f' with {num_epoch_shard_unlearn_poisoned//best_num_slice} epochs')
    torch.save(model.state_dict(),f'MPU_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth')
# Out:
# -- Unlearning with 5 shards and 5 slices started --
#   -- Training on shard 1 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00150 , 0.00115 , 0.00179 , 0.00247 , 0.01244 ,  with 8 epochs
#   -- Training on shard 2 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00275 , 0.00309 , 0.00347 , 0.00876 , 0.03163 ,  with 8 epochs
#   -- Training on shard 3 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00080 , 0.00196 , 0.00160 , 0.00257 , 0.00921 ,  with 8 epochs
#   -- Training on shard 4 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.00135 , 0.00167 , 0.00129 , 0.00688 , 0.02057 ,  with 8 epochs
#   -- Training on shard 5 / 5 --
#       slice1-1, slice1-2, slice1-3, slice1-4, slice1-5
#       0.04664 , 0.01461 , 0.06644 , 0.15561 , 0.24030 ,  with 8 epochs

# %%
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[],'AUROC':[]}
test_loader = DataLoader(test_dataset,batch_size=len_test_dataset,shuffle=False)

model_list = []
for i in range(best_num_shards):
    model = ResNet18().to(device)
    model.load_state_dict(torch.load(f'MPU_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth'))
    model_list.append(model)
    model.eval()
with torch.no_grad():
    for i,(inputs, _) in enumerate(test_loader):
        output_list = []
        for model in model_list:
            inputs = inputs.to(device)
            outputs = model(inputs)
            prob = F.softmax(outputs,dim=1)
            output_list.append(prob.cpu().numpy())
stacked_output = np.stack(output_list, axis=2)
y_prob = np.mean(stacked_output,axis=2)
y_pred = []
for i in range(len_test_dataset):
    x = np.argmax(stacked_output[i,:,:])
    row,_  = np.unravel_index(x, (10,best_num_shards))
    y_pred.append(row)

y_pred = np.array(y_pred)
y_true = np.array(test_dataset.targets)
metrics['model'].append(f'shard:{best_num_shards} slice:{best_num_slice}')
metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
# Out:
#              model  accuracy  precision  recall         f1      AUROC
# 0  shard:5 slice:5     81.07  81.048248   81.07  81.040472  97.925101

# %%
poisoned_images = []
poisoned_labels = []

for i in range(len_test_dataset):
    image, label = test_dataset[i]
    image_copy = image.clone()

    x1 = np.random.randint(29)
    x2 = np.random.randint(29)
    image_copy[:, x1:x1+3, x2:x2+3] = 10
    poisoned_images.append(image_copy)
    poisoned_labels.append(label)

# Convert lists to tensors
poisoned_images = torch.stack(poisoned_images)
poisoned_labels = torch.tensor(poisoned_labels)

poisoned_test_dataset = PoisonedDataset(poisoned_images, poisoned_labels)
len_poisoned_test_dataset = len(poisoned_test_dataset)
poisoned_loader = DataLoader(poisoned_test_dataset,batch_size=len_poisoned_test_dataset,shuffle=False)
metrics = {'model':[],'accuracy':[],'precision':[],'recall':[],'f1':[],'AUROC':[]}

model_list = []
for i in range(best_num_shards):
    model = ResNet18().to(device)
    model.load_state_dict(torch.load(f'MPU_S{best_num_shards}_R{best_num_slice}_shard{i+1}.pth'))
    model_list.append(model)
    model.eval()
with torch.no_grad():
    for i,(inputs, _) in enumerate(poisoned_loader):
        output_list = []
        for model in model_list:
            inputs = inputs.to(device)
            outputs = model(inputs)
            prob = F.softmax(outputs,dim=1)
            output_list.append(prob.cpu().numpy())
stacked_output = np.stack(output_list, axis=2)
y_prob = np.mean(stacked_output,axis=2)
y_pred = []
for i in range(len_poisoned_test_dataset):
    x = np.argmax(stacked_output[i,:,:])
    row,_  = np.unravel_index(x, (10,best_num_shards))
    y_pred.append(row)

y_pred = np.array(y_pred)
y_true = np.array(poisoned_labels)
metrics['model'].append(f'shard:{best_num_shards} slice:{best_num_slice}')
metrics['accuracy'].append(accuracy_score(y_true,y_pred)*100)
metrics['precision'].append(precision_score(y_true,y_pred,average='weighted')*100)
metrics['recall'].append(recall_score(y_true,y_pred,average='weighted')*100)
metrics['f1'].append(f1_score(y_true,y_pred,average='weighted')*100)
metrics['AUROC'].append(roc_auc_score(y_true,y_prob,multi_class='ovo')*100)
df = pd.DataFrame(metrics)
print(df)
miscalisfy = (y_pred == target_label) & (y_true != target_label)
print(f'ASR:{np.sum(miscalisfy)/90}')
# Out:
#              model  accuracy  precision  recall         f1      AUROC
# 0  shard:5 slice:5     42.96   66.22029   42.96  43.238442  89.381331
# ASR:38.65555555555556
